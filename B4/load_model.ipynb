# %% [markdown]
# # mở web python -m streamlit run app.py

# %% [markdown]
# # import lib

# %%
import streamlit as st
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import os
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("grassknoted/asl-alphabet")

print("Path to dataset files:", path)

DATA_DIR = os.path.join(
    path,
    "asl_alphabet_train",
    "asl_alphabet_train"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("grassknoted/asl-alphabet")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %% [markdown]
# # load model

# %%
loaded_model = tf.keras.models.load_model("asl_alphabet_model.h5")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 loaded_model = tf.keras.models.load_model("asl_alphabet_model.h5")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
# ...

# %%
IMG_SIZE =  64
BATCH_SIZE = 128

# %%
# chuan bi label
# cat tap train : Validation + scale anh
datagen = ImageDataGenerator(
    rescale=1./255, # chuyen doi gia tri [0,255] ve [0,1]
    validation_split=0.2
) # chia du lieu thanh tap train va validation
train_generator = datagen.flow_from_directory(
    DATA_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training' # tap train
)
class_names = train_data.class_indices
class_names = dict((v,k) for k,v in class_names.items())
print(class_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 8
#       1 # chuan bi label
#       2 # cat tap train : Validation + scale anh
#       3 datagen = ImageDataGenerator(
#       4     rescale=1./255, # chuyen doi gia tri [0,255] ve [0,1]
#       5     validation_split=0.2
#       6 ) # chia du lieu thanh tap train va validation
#       7 train_generator = datagen.flow_from_directory(
# ----> 8     DATA_DIR,
#       9     target_size=(IMG_SIZE, IMG_SIZE),
#      10     batch_size=BATCH_SIZE,
#      11     class_mode='categorical',
#      12     subset='training' # tap train
#      13 )
#      14 class_names = train_data.class_indices
#      15 class_names = dict((v,k) for k,v in class_names.items())
#
# NameError: name 'DATA_DIR' is not defined

# %%
from glob import glob
# đi qua tat ca cac file anh trong thu muc test
test_images = glob(os.path.join(path, "asl_alphabet_test","asl_aplphabet_test", "*.jpg"))
test_images[:5]  # hien thi 5 file anh dau tien
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 from glob import glob
#       2 # đi qua tat ca cac file anh trong thu muc test
# ----> 3 test_images = glob(os.path.join(path, "asl_alphabet_test","asl_aplphabet_test", "*.jpg"))
#       4 test_images[:5]  # hien thi 5 file anh dau tien
#
# NameError: name 'path' is not defined

# %% [markdown]
# # DỰ ĐOÁN

# %%
# %matplotlib inline

# %%
import cv2
test_img_path = test_images[17]
img = cv2.imread(test_img_path)
plt.rcParams['figure.figsize'] = [5, 5]
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(test_img_path.split("\\")[-1])
plt.axis('off')
plt.show()

# %%
#  du doan hinh
img = image.load_img(test_img_path, target_size=(IMG_SIZE, IMG_SIZE))
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # Scale anh
img_array = np.expand_dims(img_array, axis=0)  # Them kich thuoc batch

# du doan hinh
predictions = loaded_model.predict(img_array)
print(predictions)
predicted_class = np.argmax(predictions, axis=1)[0]
print("Predicted class:", class_names[predicted_class])
